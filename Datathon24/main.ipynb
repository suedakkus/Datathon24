# %%
import numpy as np
import pandas as pd

# %%
from datetime import datetime

# %%
train_df = pd.read_csv("datathon-2024/train.csv")
test_df = pd.read_csv("datathon-2024/test_x.csv")
# Out:
# C:\Users\sueda\AppData\Local\Temp\ipykernel_6560\3999224258.py:1: DtypeWarning: Columns (13,15,19,30,32,37,41,42) have mixed types. Specify dtype option on import or set low_memory=False.
#   train_df = pd.read_csv("datathon-2024/train.csv")

# %%
train_df.head()
# Out:
#    Basvuru Yili  Degerlendirme Puani Cinsiyet  Dogum Tarihi        Dogum Yeri  \
# 0          2014                 52.0    Erkek      4/6/1994  Altindag, Ankara
# 1          2014                 30.0    Erkek     6/11/1993           Üsküdar
# 2          2014                 18.0    Erkek     1/15/1986            Samsun
# 3          2014                 40.0    Erkek      6/4/1991        Diyarbakır
# 4          2014                 24.0    Erkek  2 Kasim 1992   Ankara/Altındağ
#
#   Ikametgah Sehri                    Universite Adi Universite Turu  \
# 0          Ankara           İHSAN DOĞRAMACI BİLKENT            Özel
# 1        İstanbul           İHSAN DOĞRAMACI BİLKENT            Özel
# 2        İstanbul  ULUSLARARASI KIBRIS ÜNİVERSİTESİ            Özel
# 3        İstanbul       İSTANBUL ŞEHİR ÜNİVERSİTESİ            Özel
# 4          Ankara          TURGUT ÖZAL ÜNİVERSİTESİ            Özel
#
#    Burslu ise Burs Yuzdesi Burs Aliyor mu?  ... Spor Dalindaki Rolunuz Nedir?  \
# 0                    100.0            Evet  ...                         Diğer
# 1                    100.0           Hayır  ...                             0
# 2                    100.0           Hayır  ...                             0
# 3                    100.0            Evet  ...                             0
# 4                    100.0            Evet  ...                             0
#
#   Aktif olarak bir STK üyesi misiniz? Hangi STK'nin Uyesisiniz?  \
# 0                               Hayır                       NaN
# 1                               Hayır                       NaN
# 2                               Hayır                       NaN
# 3                               Hayır                       NaN
# 4                               Hayır                       NaN
#
#   Stk Projesine Katildiniz Mi? Girisimcilikle Ilgili Deneyiminiz Var Mi?  \
# 0                         Evet                                     Hayır
# 1                         Evet                                      Evet
# 2                        Hayır                                     Hayır
# 3                         Evet                                     Hayır
# 4                        Hayır                                     Hayır
#
#   Girisimcilikle Ilgili Deneyiminizi Aciklayabilir misiniz?  \
# 0                                                NaN
# 1  Bilkent Cyberparkta bir şirkette Türkiye nin i...
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Ingilizce Biliyor musunuz? Ingilizce Seviyeniz?  \
# 0                        NaN                  NaN
# 1                        NaN                  NaN
# 2                        NaN                  NaN
# 3                        NaN                  NaN
# 4                        NaN                  NaN
#
#   Daha Önceden Mezun Olunduysa, Mezun Olunan Üniversite id
# 0                                                NaN     0
# 1                                                NaN     1
# 2                                                NaN     2
# 3                                                NaN     3
# 4                                                NaN     4
#
# [5 rows x 44 columns]

# %%
test_df.head()
# Out:
#    Basvuru Yili Cinsiyet      Dogum Tarihi Dogum Yeri Ikametgah Sehri  \
# 0          2023    Kadın  21.06.2002 00:00     Amasya          Amasya
# 1          2023    Kadın  11.05.2004 00:00      Konya           Konya
# 2          2023    Erkek  24.04.2002 00:00   İstanbul        İstanbul
# 3          2023    Erkek  11.03.2003 00:00     Mardin          Mardin
# 4          2023    Erkek  26.01.2002 00:00     Samsun        İstanbul
#
#                 Universite Adi Universite Turu  Burslu ise Burs Yuzdesi  \
# 0          Munzur Üniversitesi          Devlet                      NaN
# 1       Hacettepe Üniversitesi          Devlet                      NaN
# 2       Kapadokya Üniversitesi            Özel                      NaN
# 3  Mardin Artuklu Üniversitesi          Devlet                      NaN
# 4        Boğaziçi Üniversitesi          Devlet                      NaN
#
#   Burs Aliyor mu?                   Bölüm  ... Spor Dalindaki Rolunuz Nedir?  \
# 0           Hayır           Sosyal Hizmet  ...                Takım Oyuncusu
# 1           Hayır  Uluslararası İlişkiler  ...                 Bireysel Spor
# 2            Evet                   Diğer  ...                 Bireysel Spor
# 3           Hayır          İslami İlimler  ...                             -
# 4           Hayır                 İşletme  ...                             -
#
#   Aktif olarak bir STK üyesi misiniz?  \
# 0                                Evet
# 1                               Hayır
# 2                               Hayır
# 3                                Evet
# 4                                Evet
#
#                            Hangi STK'nin Uyesisiniz?  \
# 0                         Kızılay da gönüllü dağıtım
# 1                                                  -
# 2                                                  -
# 3                 Lise gezilerde liderlik yapıyordum
# 4  Toplum Gönüllüleri Vakfı'nda "Yol Arkadaşım" P...
#
#   Stk Projesine Katildiniz Mi?  Girisimcilikle Ilgili Deneyiminiz Var Mi?  \
# 0                          NaN                                      Hayır
# 1                          NaN                                      Hayır
# 2                          NaN                                      Hayır
# 3                          NaN                                      Hayır
# 4                          NaN                                       Evet
#
#   Girisimcilikle Ilgili Deneyiminizi Aciklayabilir misiniz?  \
# 0                                                  -
# 1                                                  -
# 2                                                  -
# 3                                                  -
# 4  12 aydır, yolculuğuna bir yıl önce başlamış ol...
#
#   Ingilizce Biliyor musunuz? Ingilizce Seviyeniz?  \
# 0                       Evet                  NaN
# 1                       Evet                  NaN
# 2                       Evet                  NaN
# 3                      Hayır                  NaN
# 4                       Evet                  NaN
#
#    Daha Önceden Mezun Olunduysa, Mezun Olunan Üniversite id
# 0                                                NaN      0
# 1                                                NaN      1
# 2                                                NaN      2
# 3                                                NaN      3
# 4                                                NaN      4
#
# [5 rows x 43 columns]

# %%
train_df.columns
# Out:
# Index(['Basvuru Yili', 'Degerlendirme Puani', 'Cinsiyet', 'Dogum Tarihi',
#        'Dogum Yeri', 'Ikametgah Sehri', 'Universite Adi', 'Universite Turu',
#        'Burslu ise Burs Yuzdesi', 'Burs Aliyor mu?', 'Bölüm',
#        'Universite Kacinci Sinif', 'Universite Not Ortalamasi',
#        'Daha Once Baska Bir Universiteden Mezun Olmus', 'Lise Adi',
#        'Lise Adi Diger', 'Lise Sehir', 'Lise Turu', 'Lise Bolumu',
#        'Lise Bolum Diger', 'Lise Mezuniyet Notu',
#        'Baska Bir Kurumdan Burs Aliyor mu?', 'Burs Aldigi Baska Kurum',
#        'Baska Kurumdan Aldigi Burs Miktari', 'Anne Egitim Durumu',
#        'Anne Calisma Durumu', 'Anne Sektor', 'Baba Egitim Durumu',
#        'Baba Calisma Durumu', 'Baba Sektor', 'Kardes Sayisi',
#        'Girisimcilik Kulupleri Tarzi Bir Kulube Uye misiniz?',
#        'Uye Oldugunuz Kulubun Ismi',
#        'Profesyonel Bir Spor Daliyla Mesgul musunuz?',
#        'Spor Dalindaki Rolunuz Nedir?', 'Aktif olarak bir STK üyesi misiniz?',
#        'Hangi STK'nin Uyesisiniz?', 'Stk Projesine Katildiniz Mi?',
#        'Girisimcilikle Ilgili Deneyiminiz Var Mi?',
#        'Girisimcilikle Ilgili Deneyiminizi Aciklayabilir misiniz?',
#        'Ingilizce Biliyor musunuz?', 'Ingilizce Seviyeniz?',
#        'Daha Önceden Mezun Olunduysa, Mezun Olunan Üniversite', 'id'],
#       dtype='object')

# %%
train_df.isnull().sum()
# Out:
# Basvuru Yili                                                     0
# Degerlendirme Puani                                              1
# Cinsiyet                                                       169
# Dogum Tarihi                                                   177
# Dogum Yeri                                                     791
# Ikametgah Sehri                                               2037
# Universite Adi                                                 132
# Universite Turu                                                255
# Burslu ise Burs Yuzdesi                                      42685
# Burs Aliyor mu?                                                  0
# Bölüm                                                          231
# Universite Kacinci Sinif                                       374
# Universite Not Ortalamasi                                     2753
# Daha Once Baska Bir Universiteden Mezun Olmus                37345
# Lise Adi                                                       384
# Lise Adi Diger                                               60392
# Lise Sehir                                                    1054
# Lise Turu                                                      847
# Lise Bolumu                                                   1009
# Lise Bolum Diger                                             63599
# Lise Mezuniyet Notu                                           5917
# Baska Bir Kurumdan Burs Aliyor mu?                             231
# Burs Aldigi Baska Kurum                                      43977
# Baska Kurumdan Aldigi Burs Miktari                           44162
# Anne Egitim Durumu                                             406
# Anne Calisma Durumu                                          11896
# Anne Sektor                                                  34537
# Baba Egitim Durumu                                            1007
# Baba Calisma Durumu                                          12618
# Baba Sektor                                                  20378
# Kardes Sayisi                                                 1132
# Girisimcilik Kulupleri Tarzi Bir Kulube Uye misiniz?          1829
# Uye Oldugunuz Kulubun Ismi                                   48691
# Profesyonel Bir Spor Daliyla Mesgul musunuz?                  1115
# Spor Dalindaki Rolunuz Nedir?                                32275
# Aktif olarak bir STK üyesi misiniz?                          12842
# Hangi STK'nin Uyesisiniz?                                    49518
# Stk Projesine Katildiniz Mi?                                 28308
# Girisimcilikle Ilgili Deneyiminiz Var Mi?                    12840
# Girisimcilikle Ilgili Deneyiminizi Aciklayabilir misiniz?    50526
# Ingilizce Biliyor musunuz?                                    6454
# Ingilizce Seviyeniz?                                         36533
# Daha Önceden Mezun Olunduysa, Mezun Olunan Üniversite        64706
# id                                                               0
# dtype: int64

# %%
test_df.isnull().sum()
# Out:
# Basvuru Yili                                                     0
# Cinsiyet                                                         0
# Dogum Tarihi                                                     0
# Dogum Yeri                                                       0
# Ikametgah Sehri                                                  0
# Universite Adi                                                   0
# Universite Turu                                                  0
# Burslu ise Burs Yuzdesi                                      11049
# Burs Aliyor mu?                                                  0
# Bölüm                                                            0
# Universite Kacinci Sinif                                         0
# Universite Not Ortalamasi                                        0
# Daha Once Baska Bir Universiteden Mezun Olmus                11049
# Lise Adi                                                         0
# Lise Adi Diger                                               11049
# Lise Sehir                                                       0
# Lise Turu                                                        0
# Lise Bolumu                                                      0
# Lise Bolum Diger                                             11049
# Lise Mezuniyet Notu                                              0
# Baska Bir Kurumdan Burs Aliyor mu?                               0
# Burs Aldigi Baska Kurum                                          0
# Baska Kurumdan Aldigi Burs Miktari                               0
# Anne Egitim Durumu                                               0
# Anne Calisma Durumu                                              0
# Anne Sektor                                                      0
# Baba Egitim Durumu                                               0
# Baba Calisma Durumu                                              0
# Baba Sektor                                                      0
# Kardes Sayisi                                                    0
# Girisimcilik Kulupleri Tarzi Bir Kulube Uye misiniz?             0
# Uye Oldugunuz Kulubun Ismi                                   11049
# Profesyonel Bir Spor Daliyla Mesgul musunuz?                     0
# Spor Dalindaki Rolunuz Nedir?                                    0
# Aktif olarak bir STK üyesi misiniz?                              0
# Hangi STK'nin Uyesisiniz?                                        0
# Stk Projesine Katildiniz Mi?                                 11049
# Girisimcilikle Ilgili Deneyiminiz Var Mi?                        0
# Girisimcilikle Ilgili Deneyiminizi Aciklayabilir misiniz?        0
# Ingilizce Biliyor musunuz?                                       0
# Ingilizce Seviyeniz?                                         11049
# Daha Önceden Mezun Olunduysa, Mezun Olunan Üniversite        11049
# id                                                               0
# dtype: int64

# %%
train_df['Dogum Tarihi'] = pd.to_datetime(train_df['Dogum Tarihi'], errors='coerce', dayfirst=True)

# %%
train_df['Yas'] = train_df['Basvuru Yili'] - train_df['Dogum Tarihi'].dt.year

# %%
train_df.drop(columns=["Basvuru Yili","Cinsiyet", "Dogum Yeri", "Lise Sehir", "Burslu ise Burs Yuzdesi", "Daha Once Baska Bir Universiteden Mezun Olmus", "Lise Adi Diger", "Lise Bolum Diger", "Uye Oldugunuz Kulubun Ismi", "Stk Projesine Katildiniz Mi?", "Ingilizce Seviyeniz?", "Daha Önceden Mezun Olunduysa, Mezun Olunan Üniversite"], inplace=True)

# %%
train_df.isna().sum()
# Out:
# Degerlendirme Puani                                              1
# Dogum Tarihi                                                 49930
# Ikametgah Sehri                                               2037
# Universite Adi                                                 132
# Universite Turu                                                255
# Burs Aliyor mu?                                                  0
# Bölüm                                                          231
# Universite Kacinci Sinif                                       374
# Universite Not Ortalamasi                                     2753
# Lise Adi                                                       384
# Lise Turu                                                      847
# Lise Bolumu                                                   1009
# Lise Mezuniyet Notu                                           5917
# Baska Bir Kurumdan Burs Aliyor mu?                             231
# Burs Aldigi Baska Kurum                                      43977
# Baska Kurumdan Aldigi Burs Miktari                           44162
# Anne Egitim Durumu                                             406
# Anne Calisma Durumu                                          11896
# Anne Sektor                                                  34537
# Baba Egitim Durumu                                            1007
# Baba Calisma Durumu                                          12618
# Baba Sektor                                                  20378
# Kardes Sayisi                                                 1132
# Girisimcilik Kulupleri Tarzi Bir Kulube Uye misiniz?          1829
# Profesyonel Bir Spor Daliyla Mesgul musunuz?                  1115
# Spor Dalindaki Rolunuz Nedir?                                32275
# Aktif olarak bir STK üyesi misiniz?                          12842
# Hangi STK'nin Uyesisiniz?                                    49518
# Girisimcilikle Ilgili Deneyiminiz Var Mi?                    12840
# Girisimcilikle Ilgili Deneyiminizi Aciklayabilir misiniz?    50526
# Ingilizce Biliyor musunuz?                                    6454
# id                                                               0
# Yas                                                          49930
# dtype: int64

# %%
train_df["Ikametgah Sehri"].mode()
train_df["Ikametgah Sehri"].fillna("İstanbul", inplace=True)
# Out:
# C:\Users\sueda\AppData\Local\Temp\ipykernel_6560\2860919310.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   train_df["Ikametgah Sehri"].fillna("İstanbul", inplace=True)

# %%
train_df["Universite Turu"].mode()
train_df["Universite Turu"].fillna("Devlet", inplace=True)
# Out:
# C:\Users\sueda\AppData\Local\Temp\ipykernel_6560\1548358187.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   train_df["Universite Turu"].fillna("Devlet", inplace=True)

# %%
train_df["Universite Kacinci Sinif"].mode()
train_df["Universite Kacinci Sinif"].fillna(2, inplace=True)
# Out:
# C:\Users\sueda\AppData\Local\Temp\ipykernel_6560\50851894.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   train_df["Universite Kacinci Sinif"].fillna(2, inplace=True)

# %%
train_df["Universite Not Ortalamasi"].value_counts()
train_df["Universite Not Ortalamasi"].fillna("ORTALAMA BULUNMUYOR", inplace=True)
# Out:
# C:\Users\sueda\AppData\Local\Temp\ipykernel_6560\3723416321.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   train_df["Universite Not Ortalamasi"].fillna("ORTALAMA BULUNMUYOR", inplace=True)

# %%
train_df["Lise Turu"].value_counts()
train_df["Lise Turu"].fillna("Anadolu Lisesi", inplace=True)
# Out:
# C:\Users\sueda\AppData\Local\Temp\ipykernel_6560\1976033842.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   train_df["Lise Turu"].fillna("Anadolu Lisesi", inplace=True)

# %%
train_df["Lise Bolumu"].value_counts()
train_df["Lise Bolumu"].fillna("Sayısal", inplace=True)
# Out:
# C:\Users\sueda\AppData\Local\Temp\ipykernel_6560\2233314850.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   train_df["Lise Bolumu"].fillna("Sayısal", inplace=True)

# %%
train_df["Lise Mezuniyet Notu"].value_counts()
train_df["Lise Mezuniyet Notu"].fillna("75-100", inplace=True)
# Out:
# C:\Users\sueda\AppData\Local\Temp\ipykernel_6560\50389814.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   train_df["Lise Mezuniyet Notu"].fillna("75-100", inplace=True)

# %%
train_df["Degerlendirme Puani"].fillna(0, inplace=True)
train_df["Dogum Tarihi"].fillna("Bilinmiyor", inplace=True)
train_df["Universite Adi"].fillna("Bilinmiyor", inplace=True)
train_df["Bölüm"].fillna("Bilinmiyor", inplace=True)
train_df["Lise Adi"].fillna("Bilinmiyor", inplace=True)
train_df["Baska Bir Kurumdan Burs Aliyor mu?"].fillna("Bilinmiyor", inplace=True)
train_df["Burs Aldigi Baska Kurum"].fillna("Bilinmiyor", inplace=True)
train_df["Anne Egitim Durumu"].fillna("Bilinmiyor", inplace=True)
train_df["Anne Calisma Durumu"].fillna("Bilinmiyor", inplace=True)
train_df["Anne Sektor"].fillna("Bilinmiyor", inplace=True)
train_df["Baba Calisma Durumu"].fillna("Bilinmiyor", inplace=True)
train_df["Baba Egitim Durumu"].fillna("Bilinmiyor", inplace=True)
train_df["Baba Sektor"].fillna("Bilinmiyor", inplace=True)
train_df["Kardes Sayisi"].fillna(0, inplace=True)
train_df["Girisimcilik Kulupleri Tarzi Bir Kulube Uye misiniz?"].fillna("Bilinmiyor", inplace=True)
train_df["Profesyonel Bir Spor Daliyla Mesgul musunuz?"].fillna("Bilinmiyor", inplace=True)
train_df["Spor Dalindaki Rolunuz Nedir?"].fillna("Bilinmiyor", inplace=True)
train_df["Aktif olarak bir STK üyesi misiniz?"].fillna("Bilinmiyor", inplace=True)
train_df["Hangi STK\'nin Uyesisiniz?"].fillna("Bilinmiyor", inplace=True)
train_df["Girisimcilikle Ilgili Deneyiminiz Var Mi?"].fillna("Bilinmiyor", inplace=True)
train_df["Girisimcilikle Ilgili Deneyiminizi Aciklayabilir misiniz?"].fillna("Bilinmiyor", inplace=True)
train_df["Ingilizce Biliyor musunuz?"].fillna("Bilinmiyor", inplace=True)
train_df["Baska Kurumdan Aldigi Burs Miktari"].fillna("Bilinmiyor", inplace=True)
train_df["Yas"].fillna(train_df['Yas'].median(), inplace=True)
# Out:
# C:\Users\sueda\AppData\Local\Temp\ipykernel_6560\2185255866.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   train_df["Degerlendirme Puani"].fillna(0, inplace=True)
# C:\Users\sueda\AppData\Local\Temp\ipykernel_6560\2185255866.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   train_df["Dogum Tarihi"].fillna("Bilinmiyor", inplace=True)
# C:\Users\sueda\AppData\Local\Temp\ipykernel_6560\2185255866.py:2: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Bilinmiyor' has dtype incompatible with datetime64[ns], please explicitly cast to a compatible dtype first.
#   train_df["Dogum Tarihi"].fillna("Bilinmiyor", inplace=True)
# C:\Users\sueda\AppData\Local\Temp\ipykernel_6560\2185255866.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   train_df["Universite Adi"].fillna("Bilinmiyor", inplace=True)
# C:\Users\sueda\AppData\Local\Temp\ipykernel_6560\2185255866.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   train_df["Bölüm"].fillna("Bilinmiyor", inplace=True)
# C:\Users\sueda\AppData\Local\Temp\ipykernel_6560\2185255866.py:5: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   train_df["Lise Adi"].fillna("Bilinmiyor", inplace=True)
# C:\Users\sueda\AppData\Local\Temp\ipykernel_6560\2185255866.py:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   train_df["Baska Bir Kurumdan Burs Aliyor mu?"].fillna("Bilinmiyor", inplace=True)
# C:\Users\sueda\AppData\Local\Temp\ipykernel_6560\2185255866.py:7: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   train_df["Burs Aldigi Baska Kurum"].fillna("Bilinmiyor", inplace=True)
# C:\Users\sueda\AppData\Local\Temp\ipykernel_6560\2185255866.py:8: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   train_df["Anne Egitim Durumu"].fillna("Bilinmiyor", inplace=True)
# C:\Users\sueda\AppData\Local\Temp\ipykernel_6560\2185255866.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   train_df["Anne Calisma Durumu"].fillna("Bilinmiyor", inplace=True)
# C:\Users\sueda\AppData\Local\Temp\ipykernel_6560\2185255866.py:10: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   train_df["Anne Sektor"].fillna("Bilinmiyor", inplace=True)
# C:\Users\sueda\AppData\Local\Temp\ipykernel_6560\2185255866.py:11: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   train_df["Baba Calisma Durumu"].fillna("Bilinmiyor", inplace=True)
# C:\Users\sueda\AppData\Local\Temp\ipykernel_6560\2185255866.py:12: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   train_df["Baba Egitim Durumu"].fillna("Bilinmiyor", inplace=True)
# C:\Users\sueda\AppData\Local\Temp\ipykernel_6560\2185255866.py:13: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   train_df["Baba Sektor"].fillna("Bilinmiyor", inplace=True)
# C:\Users\sueda\AppData\Local\Temp\ipykernel_6560\2185255866.py:14: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   train_df["Kardes Sayisi"].fillna(0, inplace=True)
# C:\Users\sueda\AppData\Local\Temp\ipykernel_6560\2185255866.py:15: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   train_df["Girisimcilik Kulupleri Tarzi Bir Kulube Uye misiniz?"].fillna("Bilinmiyor", inplace=True)
# C:\Users\sueda\AppData\Local\Temp\ipykernel_6560\2185255866.py:16: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   train_df["Profesyonel Bir Spor Daliyla Mesgul musunuz?"].fillna("Bilinmiyor", inplace=True)
# C:\Users\sueda\AppData\Local\Temp\ipykernel_6560\2185255866.py:17: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   train_df["Spor Dalindaki Rolunuz Nedir?"].fillna("Bilinmiyor", inplace=True)
# C:\Users\sueda\AppData\Local\Temp\ipykernel_6560\2185255866.py:18: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   train_df["Aktif olarak bir STK üyesi misiniz?"].fillna("Bilinmiyor", inplace=True)
# C:\Users\sueda\AppData\Local\Temp\ipykernel_6560\2185255866.py:19: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   train_df["Hangi STK\'nin Uyesisiniz?"].fillna("Bilinmiyor", inplace=True)
# C:\Users\sueda\AppData\Local\Temp\ipykernel_6560\2185255866.py:20: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   train_df["Girisimcilikle Ilgili Deneyiminiz Var Mi?"].fillna("Bilinmiyor", inplace=True)
# C:\Users\sueda\AppData\Local\Temp\ipykernel_6560\2185255866.py:21: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   train_df["Girisimcilikle Ilgili Deneyiminizi Aciklayabilir misiniz?"].fillna("Bilinmiyor", inplace=True)
# C:\Users\sueda\AppData\Local\Temp\ipykernel_6560\2185255866.py:22: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   train_df["Ingilizce Biliyor musunuz?"].fillna("Bilinmiyor", inplace=True)
# C:\Users\sueda\AppData\Local\Temp\ipykernel_6560\2185255866.py:23: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   train_df["Baska Kurumdan Aldigi Burs Miktari"].fillna("Bilinmiyor", inplace=True)
# C:\Users\sueda\AppData\Local\Temp\ipykernel_6560\2185255866.py:24: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   train_df["Yas"].fillna(train_df['Yas'].median(), inplace=True)

# %%
train_df["Yas"].value_counts()
# Out:
# Yas
# 21.0     53685
# 20.0      3755
# 22.0      2847
# 19.0      2227
# 23.0      1607
# 24.0       652
# 18.0       145
# 25.0        68
# 44.0        42
# 26.0        32
# 27.0        14
# 17.0        14
# 28.0        10
# 30.0         6
# 0.0          4
# 29.0         4
# 31.0         3
# 34.0         2
# 38.0         2
# 37.0         1
# 6.0          1
# 42.0         1
# 122.0        1
# 129.0        1
# 121.0        1
# Name: count, dtype: int64

# %%
train_df['Ebeveyn Eğitim Durumu'] = train_df['Anne Egitim Durumu'].astype(str) + '-' + train_df['Baba Egitim Durumu'].astype(str)

train_df['Ebeveyn Çalışma Durumu'] = train_df['Anne Calisma Durumu'].astype(str) + '-' + train_df['Baba Calisma Durumu'].astype(str)

train_df['Genel Burs Durumu'] = train_df['Burs Aliyor mu?'] + '-' + train_df['Baska Bir Kurumdan Burs Aliyor mu?']

train_df['Sosyal Katilim Skoru'] = (train_df['Aktif olarak bir STK üyesi misiniz?'] + 
                                     train_df['Girisimcilik Kulupleri Tarzi Bir Kulube Uye misiniz?'] + 
                                     train_df['Profesyonel Bir Spor Daliyla Mesgul musunuz?'])

train_df['Mezuniyet Yilina Kalan Sure'] = train_df['Universite Kacinci Sinif'].apply(
    lambda x: 4 if x == 'Hazırlık' or x == "hazırlık" else (0 if x == 'Mezun' or x == "Yüksek Lisans" or x == "Tez" else 4 - int(x))
)

# %%
def parse_range(value):
    try:
        # Split the range and calculate the average
        parts = value.split('-')
        if len(parts) == 2:
            return (float(parts[0]) + float(parts[1])) / 2
        else:
            return float(value)
    except ValueError:
        return None

# %%
train_df['Lise Mezuniyet Notu'] = train_df['Lise Mezuniyet Notu'].apply(parse_range)
train_df['Universite Not Ortalamasi'] = train_df['Universite Not Ortalamasi'].apply(parse_range)

# %%
from sklearn.impute import SimpleImputer

imputer = SimpleImputer(strategy='mean')
train_df[['Universite Not Ortalamasi']] = imputer.fit_transform(train_df[['Universite Not Ortalamasi']])
train_df[["Lise Mezuniyet Notu"]] = imputer.fit_transform(train_df[['Lise Mezuniyet Notu']])

# %%
train_df['Lise Mezuniyet Notu'] = pd.to_numeric(train_df['Lise Mezuniyet Notu'], errors='coerce')
train_df['Universite Not Ortalamasi'] = pd.to_numeric(train_df['Universite Not Ortalamasi'], errors='coerce')

train_df['Not Ortalaması Kategorisi'] = pd.cut(
    train_df['Universite Not Ortalamasi'],
    bins=[0, 1.5, 2.5, 3.0, 3.5, 4.0, 5.0],
    labels=['Çok Düşük', 'Düşük', 'Orta Düşük', 'Orta', 'Orta Yüksek', 'Yüksek']
)

# %%
target_column = train_df["id"]
train_df.drop(columns=["id"], inplace=True)
train_df["id"] = target_column

# %%
from catboost import CatBoostRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

# %%
categorical_features = [
    'Ikametgah Sehri', 'Universite Adi', 'Universite Turu', 'Burs Aliyor mu?',
    'Bölüm', 'Lise Adi', 'Lise Turu', 'Lise Bolumu', 'Baska Bir Kurumdan Burs Aliyor mu?',
    'Burs Aldigi Baska Kurum', 'Baska Kurumdan Aldigi Burs Miktari', 'Anne Egitim Durumu',
    'Anne Calisma Durumu', 'Anne Sektor', 'Baba Egitim Durumu', 'Baba Calisma Durumu',
    'Baba Sektor', 'Girisimcilik Kulupleri Tarzi Bir Kulube Uye misiniz?', 
    'Profesyonel Bir Spor Daliyla Mesgul musunuz?', 'Spor Dalindaki Rolunuz Nedir?',
    'Aktif olarak bir STK üyesi misiniz?', 'Hangi STK\'nin Uyesisiniz?', 
    'Girisimcilikle Ilgili Deneyiminiz Var Mi?', 'Girisimcilikle Ilgili Deneyiminizi Aciklayabilir misiniz?',
    'Ingilizce Biliyor musunuz?', 'Ebeveyn Eğitim Durumu', 'Ebeveyn Çalışma Durumu',
    'Genel Burs Durumu', 'Not Ortalaması Kategorisi', 'Universite Kacinci Sinif', 'Kardes Sayisi', "Sosyal Katilim Skoru"
]

# %%
for col in categorical_features:
    train_df[col] = train_df[col].astype(str)

# %%
X = train_df.drop(columns=["Degerlendirme Puani", "Dogum Tarihi"])
y = train_df["Degerlendirme Puani"]
X_test = test_df.drop(columns=["Dogum Tarihi"])

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
for feature in categorical_features:
    X[feature] = le.fit_transform(X[feature])

# %%
X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.2, random_state=101)

# %%
model = CatBoostRegressor(
    iterations=1000,learning_rate=0.04,depth=8,loss_function='RMSE',verbose=100,cat_features=categorical_features    
)

model.fit(X_train, y_train, eval_set=(X_val,y_val))

y_pred = model.predict(X_val)

rmse = np.sqrt(mean_squared_error(y_val, y_pred))
print(f'RMSE: {rmse}')
# Out:
# 0:	learn: 17.5902295	test: 17.7320587	best: 17.7320587 (0)	total: 168ms	remaining: 2m 48s
# 100:	learn: 7.4157753	test: 7.3934083	best: 7.3934083 (100)	total: 18.3s	remaining: 2m 42s
# 200:	learn: 7.0477313	test: 7.0946068	best: 7.0946068 (200)	total: 38.8s	remaining: 2m 34s
# 300:	learn: 6.8762494	test: 6.9886495	best: 6.9886495 (300)	total: 1m 1s	remaining: 2m 21s
# 400:	learn: 6.7651388	test: 6.9371136	best: 6.9371136 (400)	total: 1m 21s	remaining: 2m 1s
# 500:	learn: 6.6762892	test: 6.9050403	best: 6.9050403 (500)	total: 1m 42s	remaining: 1m 42s
# 600:	learn: 6.6052819	test: 6.8868996	best: 6.8868996 (600)	total: 2m 2s	remaining: 1m 21s
# 700:	learn: 6.5414810	test: 6.8757124	best: 6.8756132 (698)	total: 2m 23s	remaining: 1m 1s
# 800:	learn: 6.4881228	test: 6.8681360	best: 6.8681360 (800)	total: 2m 44s	remaining: 40.8s
# 900:	learn: 6.4348210	test: 6.8602978	best: 6.8602638 (895)	total: 3m 6s	remaining: 20.5s
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[46], line 5
#       1 model = CatBoostRegressor(
#       2     iterations=1000,learning_rate=0.04,depth=8,loss_function='RMSE',verbose=100,cat_features=categorical_features
#       3 )
# ----> 5 model.fit(X_train, y_train, eval_set=(X_val,y_val))
#       7 y_pred = model.predict(X_val)
#       9 rmse = np.sqrt(mean_squared_error(y_val, y_pred))
#
# File c:\Users\sueda\AppData\Local\Programs\Python\Python312\Lib\site-packages\catboost\core.py:5873, in CatBoostRegressor.fit(self, X, y, cat_features, text_features, embedding_features, graph, sample_weight, baseline, use_best_model, eval_set, verbose, logging_level, plot, plot_file, column_description, verbose_eval, metric_period, silent, early_stopping_rounds, save_snapshot, snapshot_file, snapshot_interval, init_model, callbacks, log_cout, log_cerr)
#    5871 if 'loss_function' in params:
#    5872     CatBoostRegressor._check_is_compatible_loss(params['loss_function'])
# -> 5873 return self._fit(X, y, cat_features, text_features, embedding_features, None, graph, sample_weight, None, None, None, None, baseline,
#    5874                  use_best_model, eval_set, verbose, logging_level, plot, plot_file, column_description,
#    5875                  verbose_eval, metric_period, silent, early_stopping_rounds,
#    5876                  save_snapshot, snapshot_file, snapshot_interval, init_model, callbacks, log_cout, log_cerr)
#
# File c:\Users\sueda\AppData\Local\Programs\Python\Python312\Lib\site-packages\catboost\core.py:2410, in CatBoost._fit(self, X, y, cat_features, text_features, embedding_features, pairs, graph, sample_weight, group_id, group_weight, subgroup_id, pairs_weight, baseline, use_best_model, eval_set, verbose, logging_level, plot, plot_file, column_description, verbose_eval, metric_period, silent, early_stopping_rounds, save_snapshot, snapshot_file, snapshot_interval, init_model, callbacks, log_cout, log_cerr)
#    2407 allow_clear_pool = train_params["allow_clear_pool"]
#    2409 with plot_wrapper(plot, plot_file, 'Training plots', [_get_train_dir(self.get_params())]):
# -> 2410     self._train(
#    2411         train_pool,
#    2412         train_params["eval_sets"],
#    2413         params,
#    2414         allow_clear_pool,
#    2415         train_params["init_model"]
#    2416     )
#    2418 # Have property feature_importance possibly set
#    2419 loss = self._object._get_loss_function_name()
#
# File c:\Users\sueda\AppData\Local\Programs\Python\Python312\Lib\site-packages\catboost\core.py:1790, in _CatBoostBase._train(self, train_pool, test_pool, params, allow_clear_pool, init_model)
#    1789 def _train(self, train_pool, test_pool, params, allow_clear_pool, init_model):
# -> 1790     self._object._train(train_pool, test_pool, params, allow_clear_pool, init_model._object if init_model else None)
#    1791     self._set_trained_model_attributes()
#
# File _catboost.pyx:5017, in _catboost._CatBoost._train()
#
# File _catboost.pyx:5066, in _catboost._CatBoost._train()
#
# KeyboardInterrupt:
